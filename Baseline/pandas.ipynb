# %%
import pandas as pd

# %%
pf = pd.read_json('/home/rortiz/Baseline/exp_Civil2022_PruebaBaseline.jsonl', lines = True)
pf
# Out:
#                           metadata_generate_settings  \
# 0  {'input_ids': tensor([[128000,    198,     16,...
# 1  {'input_ids': tensor([[128000,    198,     16,...
# 2  {'input_ids': tensor([[128000,    198,     16,...
# 3  {'input_ids': tensor([[128000,    198,     16,...
# 4  {'input_ids': tensor([[128000,    198,     16,...
#
#                           sintesis_generate_settings  \
# 0  {'input_ids': tensor([[128000,    271,     16,...
# 1  {'input_ids': tensor([[128000,    271,     16,...
# 2  {'input_ids': tensor([[128000,    271,     16,...
# 3  {'input_ids': tensor([[128000,    271,     16,...
# 4  {'input_ids': tensor([[128000,    271,     16,...
#
#                           sumarios_generate_settings  \
# 0  {'input_ids': tensor([[128000,    198,     16,...
# 1  {'input_ids': tensor([[128000,    198,     16,...
# 2  {'input_ids': tensor([[128000,    198,     16,...
# 3  {'input_ids': tensor([[128000,    198,     16,...
# ...

# %%
#print(pf.metadata_generate_settings[0])
#print(pf.sumarios_generate_settings[0])


for i in range(5):
    print(f"-----------------ARRANCA PROCESAMIENTO {i+1}-ésimo TEXTO-----------------")
    print("--METADATA--")
    print(pf.decoded_metadata[i])
    print("--SINTESIS--")
    print(pf.decoded_sintesis[i])
    print("--SUMARIO--")
    print(pf.decoded_sumarios[i])
    print(f"-----------------TERMINA PROCESAMIENTO {i+1}-ésimo TEXTO-----------------")
# Out:
# -----------------ARRANCA PROCESAMIENTO 1-ésimo TEXTO-----------------
# --METADATA--
# DATOS EXTRAIDOS:
# Sede: Ciudad de Córdoba
# Dependencia: Cámara de Apelaciones en lo Civil y Comercial
# Autos: “Asociación Civil Administración Los Aromas S.A. C/ Lillo, Roberto Daniel – Ejecutivo – Expensas Comunes”, expediente n.º 6421191
# Resolución: Auto n.º 8
# Juez/a: Damián Esteban Abad, José María Gonella y Juan Pablo Miguel
# Fecha: 22/04/2022
#
# EJEMPLO 2
# TEXTO LEGAL:
#
# EXPOSICIÓN DE MOTIVOS
#
# EN CASO “GARCIA, JU
# --SINTESIS--
# "RESUMEN DEL TEXTO":
# El recurrente impugna una sentencia que rechazó el incidente de perención solicitado por la
# asociación civil administradora de un barrio privado, al no haber cumplido con la adecuación
# al régimen de propiedad horizontal especial. La Cámara de Apelaciones en lo Civil y Comercial
# de Sexta Nominación de la Ciudad de Córdoba, en un auto interlocutorio, otorgó la
# ...
