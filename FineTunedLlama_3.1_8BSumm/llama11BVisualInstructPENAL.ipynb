# %%
import os

def load_files_to_list(directory):
    files_content = []

    # List all files in the specified directory
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        
        # Check if the path is a file
        if os.path.isfile(filepath):
            with open(filepath, 'r', encoding='utf-8') as file:
                # Read the content of the file and add it to the list
                files_content.append(file.read())
    
    return files_content

# Example usage:
directory_path = "/home/rortiz/FineTunedLlama_3.1_8BSumm/raw_data_P2022"  # Replace with the path to your directory
loaded_files = load_files_to_list(directory_path)

# Display the content of the loaded files
for idx, content in enumerate(loaded_files):
    print(f"File {idx + 1} content:\n{content}\n")

# %%
prompt1 = """
1. Tarea: Extraer los sigugiente datos del Texto
"Sede":
"Dependencia":
"Autos":
"Resolución":
"Juez/a":
"Fecha":

Ejemplo 1:
TEXTO LEGAL:

CAMARA DE ACUSACION
Protocolo de Autos
Nº Resolución: 141
Año: 2022 Tomo: 2 Folio: 562-564

EXPEDIENTE SAC: 2668134 - COLAUTTI, MIRIAM ESTELA - CAUSA CON IMPUTADOS
PROTOCOLO DE AUTOS. NÚMERO: 141 DEL 13/04/2022

AUTO NÚMERO:
Córdoba, trece de abril de dos mil veintidós.
VISTOS: Estos autos “Colautti, Miriam Estela p.s.a. Usurpación” (Expte. SACM
n° 2668134), con motivo del recurso de apelación presentado por la abogada Karina
del Valle Borges, patrocinante del querellante particular Sr. Jorge Alberto Ñañez, en
contra de la Sentencia n° 14 de fecha 9/3/2022, que dispuso: “… sobreseer totalmente
por prescripción de la acción penal en la presente causa a Miriam Estela Colautti por
el hecho penalmente calificados como “usurpación” (art. 181 del CP), que se le
atribuye en la presente causa, en los términos de los arts. 59 inc. 3º, 62 inc. 2º del
C.P. y 348 última parte y 350 inc. 4º del CPP ...”.
DE LOS QUE RESULTA: Que los señores vocales y la señora vocal de esta Cámara
de Acusación, reunidos con el objeto de dictar resolución en estos autos, disponen que
emitirán sus votos en el siguiente orden: 1º) Patricia Alejandra Farías; 2º) Maximiliano
Octavio Davies; 3°) Carlos Alberto Salazar.
Y CONSIDERANDO: A) Que, conforme al orden que antecede, la vocal Patricia
Alejandra Farías, dijo:
I) Que la a quo resolvió sobreseer a la imputada, mediante Sentencia n° 14. Dicha
resolución fue notificada a la abogada patrocinante del querellante particular Karina
Expediente SAC 2668134 - Pág. 1 / 5 - Nº Res. 141
del Valle Borges, mediante cédula electrónica de fecha 9/3/2022.
II) La letrada interpuso recurso de apelación contra dicho pronunciamiento ante el
juzgado de control el día 18/3/2022, órgano judicial que concedió el referido remedio
mediante decreto de fecha 21/3/2022 y elevó los autos a fin de resolver dicho planteo.
III) Radicados los autos en este tribunal, se ordenó su pase a estudio a fin de realizar
el correspondiente examen de admisibilidad (decreto de fecha 22/3/2022).
IV) Ingresando al tratamiento de los presentes actuados, entiendo que corresponde
revocar el decreto de concesión. Ello, en virtud de que de las constancias de la causa
surge que únicamente se notificó el decisorio del juez de control a la letrada
patrocinante, sin anoticiar fehacientemente al querellante, quien es el titular de los
derechos que la ley le acuerda.
Ha sido criterio inveterado de esta Cámara, que el abogado patrocinante, sin calidad de
pág. 340). En consonancia, Justo Laje Anaya y Enrique Alberto Gavier explican: “la
publicidad exigida, no es la necesaria para que la retractación llegue a conocimiento de un
número indeterminado de personas, sino que existe acuerdo en la Doctrina y en la
Jurisprudencia en que basta la publicidad propia de los actos del juicio, pudiendo disponerse
la publicación en periódicos u otros órganos de difusión únicamente en el supuesto del art.
114” (“Notas al Código Penal Argentino”, Parte Especial, T. II, p. 125; cfme., Núñez, ob.cit.,
nota 2 al art. 464, pág. 432).
II) En consecuencia, corresponde sobreseer la causa en favor de María Esther Peralta,
e imponer las costas por el orden causado (arts. 350 inc. 3°, 434, 550 y 551 CPP).
Asimismo, corresponde emplazar al pago de la tasa de justicia a las partes condenadas
en costas, determinada en la suma de pesos equivalentes a 1,5 jus, monto que deberán
abonar, en conjunto e igual proporción, una vez firme la presente sentencia, en el plazo de
quince días, bajo apercibimiento de certificar la existencia de la deuda y emitir el título
correspondiente con intereses por mora, el que será remitido a la Oficina de Tasa de Justicia
del Área de Administración del Poder Judicial para su oportuna ejecución (Código Tributario
de Córdoba y Ley Impositiva vigente).
Por lo expuesto y normas legales citadas, el Tribunal RESUELVE: I) Sobreseer
totalmente la presente causa en favor de María Esther Peralta, por haber mediado
Expediente SAC 10309961 - Pág. 5 / 6 - Nº Res. 14

conciliación, con costas por el orden causado (arts. 350 inc. 3°, 434, 550 y 551 CPP).
II) Emplazar a los condenados en costas al pago de la tasa de justicia, determinada en la
suma de pesos equivalentes a 1,5 jus, monto que deberán abonar, en conjunto e igual
proporción, una vez firme la presente sentencia, en el plazo de quince días, bajo
apercibimiento de certificar la existencia de la deuda y emitir el título correspondiente con
intereses por mora, el que será remitido a la Oficina de Tasa de Justicia del Área de
Administración del Poder Judicial para su oportuna ejecución (Código Tributario de Córdoba
y Ley Impositiva vigente).
PROTOCOLÍCESE Y HÁGASE SABER.

Texto Firmado digitalmente por:

TRABALLINI Monica Adriana
VOCAL DE CAMARA
Fecha: 2022.03.17

MAZZOTTA Maria Pia
SECRETARIO/A LETRADO DE CAMARA
Fecha: 2022.03.17

Expediente SAC 10309961 - Pág. 6 / 6 - Nº Res. 14

"RESUMEN DEL TEXTO":
La cámara sobreseyó totalmente a la parte querellada del delito de injurias. La
magistrada entendió que si bien no hubo retractación porque la parte querellada no se
desdijo de las declaraciones hechas por la red social, sino que dio explicaciones de los
motivos que la llevaron a realizar esa publicación escrita, correspondía dar cierre al
caso en el marco de la conciliación entre las partes. 

"""

# %%
prompt3 = """
1. Tarea: hace un sumario de esta resolución jurídica siguiendo estas pautas:

Contenido: Extrae y describe la doctrina jurídica o novedad clave del precedente, empleando proposiciones claras, precisas y ordenadas. Las ideas deben estar debidamente concatenadas y formuladas con un grado de abstracción que permita que el texto sea leído como una definición o argumento aplicable a otros casos con hechos similares.

Tono y estilo: Utiliza el tiempo presente del modo indicativo para resaltar la permanencia de las ideas doctrinarias.

Sumarios múltiples: Si el precedente presenta varias novedades doctrinarias, elabora sumarios independientes, cada uno autónomo y específico en su contenido. Incluye en cada uno todos los elementos necesarios para su identificación y presta atención a la precisión y especificación de los términos clave, lo cual facilitará la búsqueda y clasificación en la base de datos.

2. Tarea: Redacta "Voces" para un sumario de jurisprudencia, siguiendo las instrucciones específicas a continuación:

Palabras clave: Escribe las palabras clave o locuciones principales en negritas para que actúen como índices en la búsqueda de precedentes.
querellante particular, sobre quien recaen los derechos y obligaciones atinentes a
su carácter de parte en el proceso. Resulta insuficiente tenérselo como anoticiado
con la comunicación hecha a su patrocinante. La necesaria notificación al
querellante particular, resulta coherente con los principios y directrices referentes a
los derechos de la víctima, que garantizan que ésta sea debidamente informada
sobre los aspectos relevantes de su intervención en el proceso penal.

Voz 3: "BLOQUE DE CONSTITUCIONALIDAD. Derecho a la tutela judicial efectiva y
acceso a la justicia. Derechos de la víctima. Facultad de constituirse en
querellante particular"

Sumario 3: A partir de la última reforma constitucional y por imperio de lo prescripto en el artículo
75, inciso 22 de la Constitución Nacional, se incorporaron al bloque de
constitucionalidad instrumentos internacionales entre los que se encuentra la
Convención Americana sobre Derechos Humanos -Pacto de San José de Costa
Rica- (CADH) que consagra específicamente el derecho a la tutela judicial efectiva
y el derecho a la jurisdicción (arts. 8.1 y 25 CADH). El Código Procesal Penal de la
Provincia (CPP), al reglamentar estos derechos fundamentales consagra derechos
favorables a la víctima en su mero carácter de tal (art. 96 CPP), a la vez que admite
la posibilidad de que ella actúe en el proceso penal como acusador privado,
interviniendo en rol de querellante particular, con todos los derechos y facultades
que su carácter de parte en el proceso se le concede legalmente (arts. 7, 91 y ss.
CPP). 

Voz 4: "DERECHOS DE LA VÍCTIMA. Derecho de información. Carta Iberoamericana
de Derechos de las víctimas y Reglas de Brasilia sobre Acceso a la Justicia
de las Personas en condición de Vulnerabilidad "

Sumario 4: Dentro de los principios y directrices referidos a los derechos de la víctima, se halla
el de garantizar que ésta sea debidamente informada sobre los aspectos relevantes
de su intervención en el proceso penal, en términos sencillos y comprensibles;
especialmente en lo que concierne al curso dado a su denuncia o escrito, a las fases
relevantes del desarrollo del proceso y a las resoluciones que dicte el órgano judicial
(Carta Iberoamericana de Derechos de las Víctimas y Reglas de Brasilia sobre
Acceso a la Justicia de las Personas en condición de Vulnerabilidad). 
"""

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
import json
import time
from tqdm import tqdm
# import torch

# Cargar el modelo y el tokenizador
model_name = "meta-llama/Llama-3.1-8B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name)

# Configurar BitsAndBytes para la cuantización en 8 bits
# quantization_config = BitsAndBytesConfig(
#     load_in_4bit=True  # Set this to `True` for 8-bit quantization
# )
# Cuantización en 8 bits
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    # quantization_config=quantization_config  # Use the new argument
).half()

# print(model)

# for text in (loaded_files[:33]): #[10:20]
#     tokens = tokenizer.encode(text, add_special_tokens=False)
#     print(len(tokens))

for text in tqdm(loaded_files[:20]): #[10:20]
    start_time = time.time()
    inputs_metadata = tokenizer(
        f'{prompt1}:{text}',
        return_tensors="pt"
    ).to("cuda")
    # Extraccion de los metadatos

    metadata_generate_settings = {
        "input_ids": inputs_metadata['input_ids'],
        "attention_mask": inputs_metadata['attention_mask'],
        "pad_token_id": tokenizer.eos_token_id, 
        "max_new_tokens": 150, 
        "min_new_tokens": 20, 
        # "length_penalty": 2.0, 
        "temperature": 0.9,
        # # "no_repeat_ngram_size": 2,
        # "num_beams": 2
    }

    metadata_ids = model.generate(
        metadata_generate_settings["input_ids"], 
        attention_mask=metadata_generate_settings['attention_mask'],
        pad_token_id=metadata_generate_settings["pad_token_id"], 
        max_new_tokens=metadata_generate_settings["max_new_tokens"], 
        min_new_tokens=metadata_generate_settings["min_new_tokens"], 
        # length_penalty=metadata_generate_settings["length_penalty"], 
        temperature=metadata_generate_settings["temperature"],
        # no_repeat_ngram_size=metadata_generate_settings["no_repeat_ngram_size"],
        # num_beams=metadata_generate_settings["num_beams"]
    )

    inputs_sintesis = tokenizer(
        f'{prompt2}:{text}', return_tensors="pt"
    ).to("cuda")   

    # Generacion de la sintesis
    sintesis_generate_settings = {
        "input_ids": inputs_sintesis['input_ids'],
        "attention_mask": inputs_sintesis['attention_mask'],
        "pad_token_id": tokenizer.eos_token_id, 
        "max_new_tokens": 190, 
        "min_new_tokens": 30, 
        # "length_penalty": 2.0, 
        "temperature": 0.9,
        # "no_repeat_ngram_size": 2,
        # "num_beams": 2
    }

    sintesis_ids = model.generate(
        sintesis_generate_settings["input_ids"], 
        attention_mask=sintesis_generate_settings['attention_mask'],
        pad_token_id=sintesis_generate_settings["pad_token_id"], 
        max_new_tokens=sintesis_generate_settings["max_new_tokens"], 
        min_new_tokens=sintesis_generate_settings["min_new_tokens"], 
        # length_penalty=sintesis_generate_settings["length_penalty"], 
        temperature=sintesis_generate_settings["temperature"],
        # no_repeat_ngram_size=sintesis_generate_settings["no_repeat_ngram_size"],
        # num_beams=sintesis_generate_settings["num_beams"]
    )

    inputs_sumarios = tokenizer(
        f'{prompt3}:{text}', return_tensors="pt"
    ).to("cuda")   

    # Generacion de la sintesis
    sumarios_generate_sintesis = {
        "input_ids": inputs_sumarios['input_ids'],
        "attention_mask": inputs_sumarios['attention_mask'],
        "pad_token_id": tokenizer.eos_token_id, 
        "max_new_tokens": 400, 
        "min_new_tokens": 30, 
        # "length_penalty": 2.0, 
        "temperature": 0.9,
        # "no_repeat_ngram_size": 2,
        # "num_beams": 2
    }

    sumarios_ids = model.generate(
        sumarios_generate_sintesis["input_ids"], 
        attention_mask=sumarios_generate_sintesis['attention_mask'],
        pad_token_id=sumarios_generate_sintesis["pad_token_id"], 
        max_new_tokens=sumarios_generate_sintesis["max_new_tokens"], 
        min_new_tokens=sumarios_generate_sintesis["min_new_tokens"], 
        # length_penalty=sumarios_generate_sintesis["length_penalty"], 
        temperature=sumarios_generate_sintesis["temperature"],
        # no_repeat_ngram_size=sintesis_generate_settings["no_repeat_ngram_size"],
        # num_beams=sintesis_generate_settings["num_beams"]
    )
    end_time = time.time()
    total_time = end_time - start_time

    results = {
        "metadata_generate_settings": str(metadata_generate_settings),
        "sintesis_generate_settings": str(sintesis_generate_settings),
        "sumarios_generate_settings": str(sumarios_generate_sintesis),
        "decoded_metadata": tokenizer.decode(metadata_ids[0][len(inputs_metadata[0]):], skip_special_tokens=True),
        "decoded_sintesis": tokenizer.decode(sintesis_ids[0][len(inputs_sintesis[0]):], skip_special_tokens=True),
        "decoded_sumarios": tokenizer.decode(sumarios_ids[0][len(inputs_sumarios[0]):], skip_special_tokens=True),
        "total_time": total_time,
        "metadata_ids": metadata_ids.tolist(),
        "sintesis_ids": sintesis_ids.tolist(),
        "sumarios_ids": sumarios_ids.tolist(),
        "text": text,
        "prompt1": prompt1,
        "prompt2": prompt2,
        "prompt3": prompt3,
        "model_name": model_name
    }

    with open("/home/rortiz/FineTunedLlama_3.1_8BSumm/penal2022_Llama31_8B_ht.jsonl", 'a') as jsonl_file:
        jsonl_file.write(json.dumps(results) + '\n')

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
import json
import time
from tqdm import tqdm
# import torch

# Cargar el modelo y el tokenizador
model_name = "meta-llama/Llama-3.2-11B-Vision-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name)

# Configurar BitsAndBytes para la cuantización en 8 bits
# quantization_config = BitsAndBytesConfig(
#     load_in_4bit=True  # Set this to `True` for 8-bit quantization
# )
# Cuantización en 8 bits
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    # quantization_config=quantization_config  # Use the new argument
).half()


start_time = time.time()
inputs_metadata = tokenizer(
    f'{prompt1}:{loaded_files[3]}',
    return_tensors="pt"
).to("cuda")
# Extraccion de los metadatos

metadata_generate_settings = {
    "input_ids": inputs_metadata['input_ids'],
    "attention_mask": inputs_metadata['attention_mask'],
    "pad_token_id": tokenizer.eos_token_id, 
    "max_new_tokens": 150, 
    "min_new_tokens": 20, 
    # "length_penalty": 2.0, 
    "temperature": 0.1,
    # # "no_repeat_ngram_size": 2,
    # "num_beams": 2
}

metadata_ids = model.generate(
    metadata_generate_settings["input_ids"], 
    attention_mask=metadata_generate_settings['attention_mask'],
    pad_token_id=metadata_generate_settings["pad_token_id"], 
    max_new_tokens=metadata_generate_settings["max_new_tokens"], 
    min_new_tokens=metadata_generate_settings["min_new_tokens"], 
    # length_penalty=metadata_generate_settings["length_penalty"], 
    temperature=metadata_generate_settings["temperature"],
    # no_repeat_ngram_size=metadata_generate_settings["no_repeat_ngram_size"],
    # num_beams=metadata_generate_settings["num_beams"]
)

inputs_sintesis = tokenizer(
    f'{prompt2}:{loaded_files[3]}', return_tensors="pt"
).to("cuda")   

# Generacion de la sintesis
sintesis_generate_settings = {
    "input_ids": inputs_sintesis['input_ids'],
    "attention_mask": inputs_sintesis['attention_mask'],
    "pad_token_id": tokenizer.eos_token_id, 
    "max_new_tokens": 190, 
    "min_new_tokens": 30, 
    # "length_penalty": 2.0, 
    "temperature": 0.1,
    # "no_repeat_ngram_size": 2,
    # "num_beams": 2
}

sintesis_ids = model.generate(
    sintesis_generate_settings["input_ids"], 
    attention_mask=sintesis_generate_settings['attention_mask'],
    pad_token_id=sintesis_generate_settings["pad_token_id"], 
    max_new_tokens=sintesis_generate_settings["max_new_tokens"], 
    min_new_tokens=sintesis_generate_settings["min_new_tokens"], 
    # length_penalty=sintesis_generate_settings["length_penalty"], 
    temperature=sintesis_generate_settings["temperature"],
    # no_repeat_ngram_size=sintesis_generate_settings["no_repeat_ngram_size"],
    # num_beams=sintesis_generate_settings["num_beams"]
)

inputs_sumarios = tokenizer(
    f'{prompt3}:{loaded_files[3]}', return_tensors="pt"
).to("cuda")   

# Generacion de la sintesis
sumarios_generate_sintesis = {
    "input_ids": inputs_sumarios['input_ids'],
    "attention_mask": inputs_sumarios['attention_mask'],
    "pad_token_id": tokenizer.eos_token_id, 
    "max_new_tokens": 400, 
    "min_new_tokens": 30, 
    # "length_penalty": 2.0, 
    "temperature": 0.1,
    # "no_repeat_ngram_size": 2,
    # "num_beams": 2
}

sumarios_ids = model.generate(
    sumarios_generate_sintesis["input_ids"], 
    attention_mask=sumarios_generate_sintesis['attention_mask'],
    pad_token_id=sumarios_generate_sintesis["pad_token_id"], 
    max_new_tokens=sumarios_generate_sintesis["max_new_tokens"], 
    min_new_tokens=sumarios_generate_sintesis["min_new_tokens"], 
    # length_penalty=sumarios_generate_sintesis["length_penalty"], 
    temperature=sumarios_generate_sintesis["temperature"],
    # no_repeat_ngram_size=sintesis_generate_settings["no_repeat_ngram_size"],
    # num_beams=sintesis_generate_settings["num_beams"]
)
end_time = time.time()
total_time = end_time - start_time
