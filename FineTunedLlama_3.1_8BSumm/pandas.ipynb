# %%
import pandas as pd

# %%
pf = pd.read_json('/home/rortiz/FineTunedLlama_3.1_8BSumm/0shot.jsonl', lines = True)
pf
# Out:
#                           metadata_generate_settings  \
# 0  {'input_ids': tensor([[128000,    198,     16,...
# 1  {'input_ids': tensor([[128000,    198,     16,...
# 2  {'input_ids': tensor([[128000,    198,     16,...
# 3  {'input_ids': tensor([[128000,    198,     16,...
# 4  {'input_ids': tensor([[128000,    198,     16,...
#
#                           sintesis_generate_settings  \
# 0  {'input_ids': tensor([[128000,    271,     16,...
# 1  {'input_ids': tensor([[128000,    271,     16,...
# 2  {'input_ids': tensor([[128000,    271,     16,...
# 3  {'input_ids': tensor([[128000,    271,     16,...
# 4  {'input_ids': tensor([[128000,    271,     16,...
#
#                           sumarios_generate_settings  \
# 0  {'input_ids': tensor([[128000,    198,     16,...
# 1  {'input_ids': tensor([[128000,    198,     16,...
# 2  {'input_ids': tensor([[128000,    198,     16,...
# 3  {'input_ids': tensor([[128000,    198,     16,...
# ...

# %%
# print(pf.metadata_generate_settings[0])
# print(pf.sumarios_generate_settings[0])
# time = 0
# for i in range(2):
#     time += pf.total_time[i]
# print(time/60, "minutos")


for i in range(5):
    print("-------------------")
    print("ARRANCA LA RESPUESTA GENERADA POR EL MODELO")
    print("Modelo 1 Responde:")
    print("-------------------")
    print(pf.decoded_metadata[i])
    print("-------------------")
    print(pf.decoded_sintesis[i])
    print("-------------------")
    print(pf.decoded_sumarios[i])
    # print("Modelo 2 Responde:")
    # print("-------------------")
    # print(pf.decoded_metadata2[i])
    # print("-------------------")
    # print(pf.decoded_sintesis2[i])
    # print("-------------------")
    # print(pf.decoded_sumarios2[i])
    print("TERMINA LA RESPUESTA GENERADA POR EL MODELO")
# Out:
# -------------------
# ARRANCA LA RESPUESTA GENERADA POR EL MODELO
# Modelo 1 Responde:
# -------------------
# 2. Preguntas
# 1. ¿Cuál es la fecha de la sentencia?
# 2. ¿Qué tipo de recurso se interpone en el caso?
# 3. ¿Cuál es el motivo del recurso de casación?
# 4. ¿Qué es lo que se discute en la materia puesta en discusión?
# 5. ¿Qué es lo que se plantea como cuestión preliminar?
# 6. ¿Qué se entiende por adecuación en el contexto de la propiedad horizontal?
# 7. ¿Cuál es la doctrina y la jurisprudencia que se cita en relación con la adecuación?
# 8. ¿Qué se entiende por certificado de deuda en el contexto
# -------------------
# 2. TAREA:
#
# ...
