# %%
131072 tokens soporta el modelo

# %%
l = [8617,
10297,
5171,
11461,
8808,
8705,
28908,
21156,
8692,
15257,
14552,
14196,
10432,
10138,
14665,
6456,
5420,
14523,
10556,
7325,
15798,
2840,
4624,
5017,
5406,
3983,
25580,
10017,
15208,
8728,
11866,
9294,
15180,
7124,
7070,
10167,
22996,
5610,
4873,
5043,
13648,
30062,
18964,
40608,
4261,
22556,
34913,
38570,
11054,
4476,
28075,
4880,
15513,
6391,
11124,
18167,
7742,
7941,
2581,
15665,
30414,
5880,
4647,
23346,
5736,
17413,
28122,
21731,
3958,
32459,
11717,
17633,
3275,
10413,
14407,
15145,
4441,
9532,
5314,
21065,
8735,
7762,
8459,
8649,
21185,
33168,
25167,
7285]

l.sort()
l

# %%
listapenal = [252251,
86655,
46756,
3464,
45872,
2780,
11528,
101985,
19445,
11336,
40073,
15910,
8305,
5112,
11765,
9094,
8494,
34939,
14334,
5777,
9930,
6022,
9878,
6527,
6809,
9025,
6482,
161888,
128833,
5344]

# %%
import matplotlib.pyplot as plt


# Crear el histograma
plt.figure(figsize=(10, 6))
plt.hist(listapenal, bins=15, color='skyblue', edgecolor='black')

# Agregar títulos y etiquetas
plt.title('Distribución de la cantidad de tokens por texto')
plt.xlabel('Cantidad de tokens')
plt.ylabel('Frecuencia')

# Mostrar el gráfico
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
